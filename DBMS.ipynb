# %% [markdown]
# <a href="https://colab.research.google.com/github/AdarshKhatri01/DBMS-Notes/blob/main/DBMS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **📌 ENTITY, ENTITY TYPE, AUR ENTITY SET**
#
# ### **1️⃣ ENTITY KYA HAI?**
# 🔹 **Entity** ek **real-world object ya concept** hai **jiske baare mein hum data store kar sakte hain aur jo identifiable ho**.
#
# ### **📌 Examples:**
# ✅ **Student** – *Amit ek student hai, toh ye ek entity hai.*
# ✅ **Car** – *Honda City ek car hai, toh ye ek entity hai.*
# ✅ **Book** – *Mathematics NCERT ek book hai, toh ye bhi ek entity hai.*
#
# 👉 **Bas simple baat ye hai ki entity koi bhi cheez ho sakti hai jo real world me exist karti hai aur jiska data store ho sakta hai!**
#
# ---
#
# ### **2️⃣ ENTITY TYPE KYA HAI?**
# 🔹 **Entity Type** ek **category** hai jisme **same type ki multiple entities grouped hoti hain**.
# 🔹 **Har entity type ke attributes hote hain** jo usko describe karte hain.
#
# ### **📌 Example:**
# 🟢 **Student Entity Type:**
#    - Attributes: **Roll Number, Name, Age, Course**
#    - Entities: *Amit (101, B.Tech), Priya (102, B.Sc), Rohan (103, B.Com)*
#
# 🟢 **Car Entity Type:**
#    - Attributes: **Model, Company, Color, Price**
#    - Entities: *Swift (Maruti, Red), BMW X5 (BMW, Black), Tesla Model S (Tesla, White)*
#
# 👉 **Samajhne ka easy tareeka – Agar ek individual student entity hai, toh "Student" ek entity type hoga jo sabhi students ko define karta hai!**
#
# ---
#
# ### **3️⃣ ENTITY SET KYA HAI?**
# 🔹 **Entity Set** ek **group of similar entities ka collection** hota hai.
# 🔹 Ek **entity set ek entity type ke sabhi objects ko store karta hai**.
#
# ### **📌 Example:**
# 🟢 **Student Entity Set:**
#    - **Entity Type:** Student
#    - **Entities:** Amit, Priya, Rohan, Suresh (*College ke sabhi students ka collection*).
#
# 🟢 **Car Entity Set:**
#    - **Entity Type:** Car
#    - **Entities:** Swift, BMW X5, Tesla Model S (*Showroom me available sabhi cars ka collection*).
#
# 👉 **Bas simple baat – Entity Set ka matlab ek entity type ke andar aane wali sabhi entities ka group!**
#
# ---
#
# ### **📌 EASY SUMMARY TABLE**
#
# | Concept | Definition | Example |
# |---------|------------|---------|
# | **Entity** | Ek individual object ya concept | *Amit (Student), BMW X5 (Car), Order#1234 (Order)* |
# | **Entity Type** | Ek category ya class jo same type ki entities ko group karti hai | *Student (Roll No, Name, Age, Course)* |
# | **Entity Set** | Ek entity type ke sabhi objects ka collection | *College ke sabhi students ka group* |
#
# ---
# ![Screenshot 2025-02-16 161124.png](data:image/png;base64,...)
#
# ---
#
# ![image.png](data:image/png;base64,...)
#
# ---
#
# ### **💡 SIMPLE TARIKA YAAD RAKHNE KA**
# 1️⃣ **Entity** – Ek specific cheez ya insaan (*Ek student, Ek car, Ek book*).
# 2️⃣ **Entity Type** – Us category ka naam (*Student, Car, Book*).
# 3️⃣ **Entity Set** – Us category ke andar aane wali sabhi cheezein (*Sabhi students, Sabhi cars, Sabhi books*).

# %% [markdown]
# ## **📌 Strong Entity vs Weak Entity – Aasaan Bhasha Me Samjho**
#
# ### **1️⃣ Strong Entity Kya Hai?**
# ✔ **Strong Entity wo entity hoti hai jo apni pehchaan khud rakh sakti hai.**
# ✔ Iske **paas apni ek Primary Key hoti hai**, jo unique hoti hai.
# ✔ Ye **kisi aur entity par dependent nahi hoti**.
#
# #### **📝 Example (Strong Entity Table)**
# | **Student_ID (Primary Key)** | **Name**  | **Course**  |
# |----------------|---------|-------------|
# | 101            | Amit    | B.Tech      |
# | 102            | Riya    | B.Sc        |
# | 103            | Suresh  | B.Com       |
#
# ✅ **Student_ID har student ke liye unique hai.**
# ✅ **Har student ki apni pehchaan hai bina kisi aur ki madad ke.**
# ✅ **Isliye Student ek Strong Entity hai.**
#
# ---
#
# ### **2️⃣ Weak Entity Kya Hai?**
# ✔ **Weak Entity wo entity hoti hai jo apni pehchaan khud nahi bana sakti.**
# ✔ **Iske paas apni Primary Key nahi hoti, balki ye kisi aur Strong Entity par dependent hoti hai.**
# ✔ Isme ek **Foreign Key hoti hai**, jo ek Strong Entity ki Primary Key hoti hai.
#
# #### **📝 Example (Weak Entity Table - Dependent)**
# | **Dependent_ID** | **Dependent_Name** | **Relation** | **Student_ID (Foreign Key)** |
# |-----------------|-----------------|-----------|----------------------|
# | 1              | Ananya          | Sister    | 101                  |
# | 2              | Rohan           | Brother   | 101                  |
# | 3              | Priya           | Mother    | 102                  |
# | 4              | Sohan           | Father    | 103                  |
#
# ✅ **Yahan "Dependent_Name" unique nahi hai.**
# ✅ **Isliye "Student_ID" ka use karna padta hai, jo ek Foreign Key hai.**
# ✅ **Ye Strong Entity (Student) ke bina exist nahi kar sakti.**
# ✅ **Isliye Dependent ek Weak Entity hai.**
#
# ---
#
# ## **📌 Main Differences Table Me**
#
# | **Feature** | **Strong Entity** | **Weak Entity** |
# |------------|----------------|---------------|
# | **Definition** | Apni pehchaan khud rakh sakti hai | Kisi aur entity se pehchaan milti hai |
# | **Primary Key** | Apni hoti hai | Apni nahi hoti |
# | **Foreign Key** | Nahi hoti | Strong Entity ki Foreign Key hoti hai |
# | **Dependency** | Independent hoti hai | Kisi aur entity par dependent hoti hai |
# | **ER Diagram Symbol** | **Single Rectangle** | **Double Rectangle** |
# | **Example** | Student, Employee, Car | Dependent, Bill, Order Item |
#
# ---
#
# ### **📌 Easy Summary**
# ✔ **Strong Entity** – Apni pehchaan khud bana sakti hai (*Student, Car, Employee*).
# ✔ **Weak Entity** – Apni pehchaan kisi aur Entity se leti hai (*Dependent, Bill Details*).
# ✔ **Weak Entity ke liye ek Foreign Key zaroori hoti hai.**
